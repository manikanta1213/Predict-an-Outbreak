# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Flu.xlsx")

# %%
df.head()
# Out:
#   WHOREGION          ITZ COUNTRY/AREA/TERRITORY COUNTRY_CODE ORIGIN_SOURCE  \
# 0       AFR  FLU_NRT_AFR                Algeria          DZA    NOTDEFINED
# 1       AFR  FLU_NRT_AFR                Algeria          DZA    NOTDEFINED
# 2       AFR  FLU_NRT_AFR                Algeria          DZA    NOTDEFINED
# 3       AFR  FLU_NRT_AFR                Algeria          DZA    NOTDEFINED
# 4       AFR  FLU_NRT_AFR                Algeria          DZA    NOTDEFINED
#
#    ISO_YEAR  ISO_WEEK                 ISO_SDATE  SPEC_RECEIVED_NB  \
# 0      2021        46  2021-11-15T06:00:00.000Z              56.0
# 1      2021        47  2021-11-22T06:00:00.000Z              56.0
# 2      2021        48  2021-11-29T06:00:00.000Z              39.0
# 3      2021        49  2021-12-06T06:00:00.000Z              46.0
# 4      2021        50  2021-12-13T06:00:00.000Z              32.0
#
#    SPEC_PROCESSED_NB  ...  AH5  ANOTSUBTYPED  INF_A  BVIC  BYAM  \
# ...

# %%
df.WHOREGION.value_counts()
# Out:
# EUR     5420
# AMR     3536
# AFR     1426
# EMR      999
# WPR      804
# SEAR     738
# Name: WHOREGION, dtype: int64

# %%
df['COUNTRY/AREA/TERRITORY'].value_counts()
# Out:
# Panama                                   123
# Timor-Leste                              121
# United Kingdom, Northern Ireland         120
# United Kingdom, Scotland                 120
# Republic of Moldova                      120
#                                         ...
# Gabon                                     23
# Malta                                     12
# Zimbabwe                                   9
# Democratic People's Republic of Korea      9
# Turkmenistan                               2
# Name: COUNTRY/AREA/TERRITORY, Length: 162, dtype: int64

# %%
df['ISO_YEAR'].value_counts()
# Out:
# 2022    9836
# 2021    3087
# Name: ISO_YEAR, dtype: int64

# %%
df.hist(edgecolor= 'black',figsize=(14,12))
plt.show()

# %%
year = []
month = []
for i in df['ISO_SDATE']:
    s = i.split("-")
    year.append(s[0])
    month.append(s[1])

# %%
df['YEAR'] = year
df['MONTH'] = month

# %%
df.head()
# Out:
#   WHOREGION          ITZ COUNTRY/AREA/TERRITORY COUNTRY_CODE ORIGIN_SOURCE  \
# 0       AFR  FLU_NRT_AFR                Algeria          DZA    NOTDEFINED
# 1       AFR  FLU_NRT_AFR                Algeria          DZA    NOTDEFINED
# 2       AFR  FLU_NRT_AFR                Algeria          DZA    NOTDEFINED
# 3       AFR  FLU_NRT_AFR                Algeria          DZA    NOTDEFINED
# 4       AFR  FLU_NRT_AFR                Algeria          DZA    NOTDEFINED
#
#    ISO_YEAR  ISO_WEEK                 ISO_SDATE  SPEC_RECEIVED_NB  \
# 0      2021        46  2021-11-15T06:00:00.000Z              56.0
# 1      2021        47  2021-11-22T06:00:00.000Z              56.0
# 2      2021        48  2021-11-29T06:00:00.000Z              39.0
# 3      2021        49  2021-12-06T06:00:00.000Z              46.0
# 4      2021        50  2021-12-13T06:00:00.000Z              32.0
#
#    SPEC_PROCESSED_NB  ...  INF_A  BVIC  BYAM  BNOTDETERMINED  INF_B  INF_ALL  \
# ...

# %%
df = df.drop(['ISO_SDATE','COUNTRY_CODE','ITZ', 'WHOREGION', 'ORIGIN_SOURCE'],axis=1)

# %%
df.head()
# Out:
#   COUNTRY/AREA/TERRITORY  ISO_YEAR  ISO_WEEK  SPEC_RECEIVED_NB  \
# 0                Algeria      2021        46              56.0
# 1                Algeria      2021        47              56.0
# 2                Algeria      2021        48              39.0
# 3                Algeria      2021        49              46.0
# 4                Algeria      2021        50              32.0
#
#    SPEC_PROCESSED_NB  AH1  AH1N12009  AH3  AH5  ANOTSUBTYPED  INF_A  BVIC  \
# 0               56.0  NaN        0.0  3.0  0.0           0.0    3.0   0.0
# 1               56.0  NaN        0.0  5.0  0.0           0.0    5.0   0.0
# 2               39.0  NaN        0.0  9.0  0.0           0.0    9.0   0.0
# 3               46.0  NaN        0.0  8.0  0.0           0.0    8.0   0.0
# 4               32.0  NaN        0.0  3.0  0.0           0.0    3.0   0.0
#
#    BYAM  BNOTDETERMINED  INF_B  INF_ALL  INF_NEGATIVE  ILI_ACTIVITY  YEAR  \
# ...

# %%
inf_a = df[['COUNTRY/AREA/TERRITORY','YEAR','MONTH','ISO_WEEK','INF_A']]

# %%
inf_a
# Out:
#       COUNTRY/AREA/TERRITORY  YEAR MONTH  ISO_WEEK  INF_A
# 0                    Algeria  2021    11        46    3.0
# 1                    Algeria  2021    11        47    5.0
# 2                    Algeria  2021    11        48    9.0
# 3                    Algeria  2021    12        49    8.0
# 4                    Algeria  2021    12        50    3.0
# ...                      ...   ...   ...       ...    ...
# 12918               Viet Nam  2022    09        37    3.0
# 12919               Viet Nam  2022    09        38    5.0
# 12920               Viet Nam  2022    09        39    3.0
# 12921               Viet Nam  2022    10        40    2.0
# 12922               Viet Nam  2022    10        41    0.0
#
# [12923 rows x 5 columns]

# %% [markdown]
# # START #############

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Flu.xlsx")

# %%
year = []
month = []
for i in df['ISO_SDATE']:
    s = i.split("-")
    year.append(s[0])
    month.append(s[1])
df['YEAR']=year

# %%
original = df

# %%
date = []
for i in df['ISO_SDATE']:
    date.append(i.split("T")[0])
df['DATE']=date

# %%
data = df[['DATE','COUNTRY/AREA/TERRITORY','INF_A']]

# %%
data.head()
# Out:
#          DATE COUNTRY/AREA/TERRITORY  INF_A
# 0  2021-11-15                Algeria    3.0
# 1  2021-11-22                Algeria    5.0
# 2  2021-11-29                Algeria    9.0
# 3  2021-12-06                Algeria    8.0
# 4  2021-12-13                Algeria    3.0

# %%
df=data.groupby(['COUNTRY/AREA/TERRITORY','DATE'])['INF_A'].sum() \
            .groupby(['COUNTRY/AREA/TERRITORY']).max().sort_values() \
            .groupby(['COUNTRY/AREA/TERRITORY']).sum().sort_values(ascending = False)

top10 = pd.DataFrame(df).head(10)
top10
# Out:
#                               INF_A
# COUNTRY/AREA/TERRITORY
# United States of America    16617.0
# Canada                       5274.0
# Denmark                      3385.0
# Sweden                       2472.0
# France                       2318.0
# Norway                       2153.0
# Iran (Islamic Republic of)   2051.0
# China                        1901.0
# Spain                        1729.0
# Switzerland                  1646.0

# %%
import plotly.express as px
figure = px.bar(top10, x=top10.index, y='INF_A', labels={'x':'COUNTRY/AREA/TERRITORY'},
             color="INF_A", color_continuous_scale=px.colors.sequential.Brwnyl)
figure.update_layout(title_text='Confirmed INF-A cases by country')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
figure = px.bar(df, x=df.index, y='INF_A', labels={'x':'COUNTRY/AREA/TERRITORY'},
             color="INF_A", color_continuous_scale=px.colors.sequential.Brwnyl)
figure.update_layout(title_text='Confirmed INF-A cases by country')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_by_date = pd.DataFrame(data.groupby(['COUNTRY/AREA/TERRITORY','DATE'])['INF_A'].sum().sort_values().reset_index())
df_by_date.head(10)
# Out:
#   COUNTRY/AREA/TERRITORY        DATE  INF_A
# 0            Afghanistan  2021-09-27    0.0
# 1              Lithuania  2022-08-08    0.0
# 2              Lithuania  2022-08-01    0.0
# 3              Lithuania  2022-07-25    0.0
# 4              Lithuania  2022-07-18    0.0
# 5              Lithuania  2022-07-11    0.0
# 6              Lithuania  2022-07-04    0.0
# 7              Lithuania  2022-06-27    0.0
# 8              Lithuania  2022-06-20    0.0
# 9              Lithuania  2022-06-13    0.0

# %%
figure = px.bar(df_by_date.loc[(df_by_date['COUNTRY/AREA/TERRITORY'] == 'United States of America') &(df_by_date.DATE >= '2020-01-22')].sort_values('INF_A',ascending = False), 
             x='DATE', y='INF_A', color="INF_A", color_continuous_scale=px.colors.sequential.BuGn)
figure.update_layout(title_text='Confirmed INF-A cases per day in US')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df=data.groupby(['DATE','COUNTRY/AREA/TERRITORY']).agg('sum').reset_index()
df.tail(10)
# Out:
#             DATE            COUNTRY/AREA/TERRITORY  INF_A
# 8670  2022-11-14                         Sri Lanka   11.0
# 8671  2022-11-14                            Sweden   55.0
# 8672  2022-11-14                          Thailand   18.0
# 8673  2022-11-14                       Timor-Leste    0.0
# 8674  2022-11-14                              Togo    0.0
# 8675  2022-11-14                           Ukraine  193.0
# 8676  2022-11-14  United Kingdom, Northern Ireland   56.0
# 8677  2022-11-14          United Kingdom, Scotland  317.0
# 8678  2022-11-14                        Uzbekistan    0.0
# 8679  2022-11-14                            Zambia    1.0

# %%
data['DATE'] = pd.to_datetime(data['DATE'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import matplotlib.pyplot as plt

case='Confirmed'
def timeCompare(time,*argv):
    Coun1=argv[0]
    Coun2=argv[1]
    f,ax=plt.subplots(figsize=(16,5))
    labels=argv  
    country=df.loc[(df['COUNTRY/AREA/TERRITORY']==Coun1)]
    plt.plot(country['DATE'],country['INF_A'],linewidth=2)
    plt.xticks([])
    plt.legend(labels)
    ax.set(title=' Evolution of actual cases',ylabel='Number of cases' )

    country2=df.loc[df['COUNTRY/AREA/TERRITORY']==Coun2]
    #country2['Date']=country2['Date']-datetime.timedelta(days=time)
    plt.plot(country2['DATE'],country2['INF_A'],linewidth=2)
    #plt.xticks([])
    plt.legend(labels)
    ax.set(title=' Evolution of cases in %d days difference '%time ,ylabel='Number of %s cases'%case )

# %%
timeCompare(7,'United States of America','Sweden')

# %%
data['WEEK'] = original['ISO_WEEK']
data['YEAR'] = original['YEAR']
data_us = data[data['COUNTRY/AREA/TERRITORY']=='United States of America']
data_us = data_us[data_us['YEAR']=='2022']
df_date = pd.DataFrame(data_us.groupby(['DATE','WEEK'])['INF_A'].sum().sort_values().reset_index())
df_date = df_date.sort_values(by=['WEEK'])
df_date
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          DATE  WEEK    INF_A
# 28 2022-01-03     1   4764.0
# 25 2022-01-10     2   3628.0
# 21 2022-01-17     3   2921.0
# 18 2022-01-24     4   2314.0
# 16 2022-01-31     5   2078.0
# 19 2022-02-07     6   2490.0
# 22 2022-02-14     7   3096.0
# ...

# %%
import plotly.express as px
import plotly.graph_objects as go
week_num=[]
weekwise_confirmed=[]
w=1
for i in df_date['WEEK']:
    weekwise_confirmed.append(df_date[df_date["WEEK"]==i]["INF_A"].iloc[-1])
    week_num.append(w)
    w=w+1

fig=go.Figure()
fig.add_trace(go.Scatter(x=week_num, y=weekwise_confirmed,
                    mode='lines+markers',
                    name='Weekly Growth of Confirmed Cases'))
fig.update_layout(title="Weekly Growth of Cases",
                 xaxis_title="Week Number",yaxis_title="Number of Cases",legend=dict(x=0,y=1,traceorder="normal"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig, ax1 = plt.subplots(1,figsize=(18,5))
sns.barplot(x=week_num,y=weekwise_confirmed,ax=ax1)
ax1.set_xlabel("Week Number")
ax1.set_ylabel("Number of Confirmed Cases")
ax1.set_title("Weekly increase in Number of Confirmed Cases")
# Out:
# Text(0.5, 1.0, 'Weekly increase in Number of Confirmed Cases')

# %%
test = data[data['COUNTRY/AREA/TERRITORY']=='United States of America']
test = pd.DataFrame(test.groupby(['DATE','WEEK'])['INF_A'].sum().sort_values().reset_index())
test = test.sort_values(by=['DATE'])
test
# Out:
#          DATE  WEEK    INF_A
# 0  2021-09-27    39     28.0
# 3  2021-10-04    40    133.0
# 2  2021-10-11    41    119.0
# 1  2021-10-18    42     81.0
# 4  2021-10-25    43    156.0
# 9  2021-11-01    44    318.0
# 15 2021-11-08    45    570.0
# 20 2021-11-15    46   1218.0
# 23 2021-11-22    47   1872.0
# 33 2021-11-29    48   3368.0
# 40 2021-12-06    49   5106.0
# 54 2021-12-13    50   8094.0
# 55 2021-12-20    51   8549.0
# 52 2021-12-27    52   7610.0
# 38 2022-01-03     1   4764.0
# 35 2022-01-10     2   3628.0
# 30 2022-01-17     3   2921.0
# 27 2022-01-24     4   2314.0
# 25 2022-01-31     5   2078.0
# 28 2022-02-07     6   2490.0
# 31 2022-02-14     7   3096.0
# 32 2022-02-21     8   3312.0
# 36 2022-02-28     9   4224.0
# 39 2022-03-07    10   4804.0
# 43 2022-03-14    11   5559.0
# 45 2022-03-21    12   6184.0
# 46 2022-03-28    13   6344.0
# 50 2022-04-04    14   7371.0
# 53 2022-04-11    15   7652.0
# 49 2022-04-18    16   7134.0
# 48 2022-04-25    17   7033.0
# ...

# %%
month = []
year=[]
for i in test['DATE']:
    year.append(int(str(i).split("-")[0]))
    month.append(int(str(i).split("-")[1]))

# %%
test['MONTH'] = month
test['YEAR'] = year

# %%
test.head()
# Out:
#         DATE  WEEK  INF_A  MONTH  YEAR
# 0 2021-09-27    39   28.0      9  2021
# 3 2021-10-04    40  133.0     10  2021
# 2 2021-10-11    41  119.0     10  2021
# 1 2021-10-18    42   81.0     10  2021
# 4 2021-10-25    43  156.0     10  2021

# %%
import numpy as np
X = test[['WEEK','MONTH','YEAR']]
y = test['INF_A']

# %%
len(test)
# Out:
# 59

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
print("Root Mean Square Error for Linear Regression: ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Root Mean Square Error for Linear Regression:  9778.382829690936

# %%
test.tail()
# Out:
#          DATE  WEEK    INF_A  MONTH  YEAR
# 34 2022-10-10    41   3404.0     10  2022
# 41 2022-10-17    42   5370.0     10  2022
# 56 2022-10-24    43   9758.0     10  2022
# 58 2022-10-31    44  16617.0     10  2022
# 57 2022-11-07    45  16096.0     11  2022

# %%
y_pred
# Out:
# array([1342.07218966, 1256.24801803, 1170.4238464 , 1084.59967477,
#         998.77550315,  883.49046043])

# %%
plt.figure(figsize=(11,6))
prediction_linreg=model.predict(X_test)
linreg_output=[]
for i in prediction_linreg:
    linreg_output.append(i)

fig=go.Figure()
fig.add_trace(go.Scatter(x=X_test.index, y=y_test,
                    mode='lines+markers',name="Train Data for Confirmed Cases"))
fig.add_trace(go.Scatter(x=X_test.index, y=prediction_linreg,
                    mode='lines',name="Linear Regression Best Fit Line",
                    line=dict(color='black', dash='dot')))
fig.update_layout(title="Confirmed Cases Linear Regression Prediction",
                 xaxis_title="Date",yaxis_title="Confirmed Cases",legend=dict(x=0,y=1,traceorder="normal"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.svm import SVR
svm=SVR(C=1,degree=6,kernel='poly',epsilon=0.01)

# %%
X = test[['WEEK','MONTH','YEAR']]
y = test['INF_A']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Fitting model on the training data
svm.fit(X_train,y_train)
# Out:
# SVR(C=1, degree=6, epsilon=0.01, kernel='poly')

# %%
prediction_valid_svm=svm.predict(X_test)

# %%
print("Root Mean Square Error for Support Vectore Machine: ",np.sqrt(mean_squared_error(y_test,prediction_valid_svm)))
# Out:
# Root Mean Square Error for Support Vectore Machine:  8760.559637059738

# %%
plt.figure(figsize=(11,6))
prediction_svm=svm.predict(X)
fig=go.Figure()
fig.add_trace(go.Scatter(x=X.index, y=y,
                    mode='lines+markers',name="Train Data for Confirmed Cases"))
fig.add_trace(go.Scatter(x=X.index, y=prediction_svm,
                    mode='lines',name="Support Vector Machine Best fit Kernel",
                    line=dict(color='black', dash='dot')))
fig.update_layout(title="Confirmed Cases Support Vectore Machine Regressor Prediction",
                 xaxis_title="Date",yaxis_title="Confirmed Cases",legend=dict(x=0,y=1,traceorder="normal"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

# %%
def fit_model(df,future):
    m = Prophet(daily_seasonality=True)
    m.fit(df)
    forecast = m.predict(future)
    return m, forecast, future

def fb_plots(m, fore):
    return plot_plotly(m, forecast)

def fb_subplots(m, fore):
    return m.plot(forecast), m.plot_components(forecast)

# %%
data = pd.DataFrame()
data['ds'] = test['DATE']
data['y'] = test['INF_A']
train_data = data[:50]
test_data = data[50:]
future = pd.DataFrame()
future['ds'] = test_data['ds']

# %%
model, forecast, future =fit_model(train_data, future)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpe0lj_cn1/518q1lfm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpe0lj_cn1/08p8k4uq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33855', 'data', 'file=/tmp/tmpe0lj_cn1/518q1lfm.json', 'init=/tmp/tmpe0lj_cn1/08p8k4uq.json', 'output', 'file=/tmp/tmpe0lj_cn1/prophet_model_ee2zjzk/prophet_model-20221128000757.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 00:07:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 00:07:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
fb_plots(model, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fb_subplots(model, forecast)
# Out:
# (<Figure size 720x432 with 1 Axes>, <Figure size 648x432 with 2 Axes>)

# %%
forecast['yhat'], test_data['y']
# Out:
# (0    2775.209443
#  1    2759.171918
#  2    2743.134393
#  3    2727.096868
#  4    2711.059343
#  5    2695.021818
#  6    2678.984294
#  7    2662.946769
#  8    2646.909244
#  Name: yhat, dtype: float64, 16      584.0
#  19      912.0
#  22     1423.0
#  26     2277.0
#  34     3404.0
#  41     5370.0
#  56     9758.0
#  58    16617.0
#  57    16096.0
#  Name: y, dtype: float64)

# %%
print("Root Mean Squared Error for Prophet Model: ",np.sqrt(mean_squared_error(test_data["y"],forecast['yhat'])))
# Out:
# Root Mean Squared Error for Prophet Model:  7019.81771740408

# %%
prophet_c=Prophet(interval_width=0.95,weekly_seasonality=True,)

# %%
prophet_c.fit(data)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpe0lj_cn1/xhhz9vpv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpe0lj_cn1/z3q319fe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65400', 'data', 'file=/tmp/tmpe0lj_cn1/xhhz9vpv.json', 'init=/tmp/tmpe0lj_cn1/z3q319fe.json', 'output', 'file=/tmp/tmpe0lj_cn1/prophet_modelnpuj06hj/prophet_model-20221127221252.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 22:12:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:12:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast_c=prophet_c.make_future_dataframe(periods=20)
forecast_confirmed=forecast_c.copy()

# %%
confirmed_forecast=prophet_c.predict(forecast_c)

# %%
print("Root Mean Squared Error for Prophet Model: ",np.sqrt(mean_squared_error(data["y"],confirmed_forecast['yhat'].head(data.shape[0]))))
# Out:
# Root Mean Squared Error for Prophet Model:  3568.257637875152

# %%
print(prophet_c.plot(confirmed_forecast))
# Out:
# Figure(720x432)

# %%
print(prophet_c.plot_components(confirmed_forecast))
# Out:
# Figure(648x432)
